# %%
print("Hello World!")

# %%
Hi! My name is Jaime. I have some programming experience under my belt, but I'm eager to deepen my skills, particularly in data analysis and Python. I'm looking forward to learning as much as I can and growing with the help of this program!
